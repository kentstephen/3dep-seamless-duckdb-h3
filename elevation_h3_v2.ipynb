# %%
# /// script
# requires-python = ">=3.11"
# dependencies = [
#     "duckdb==1.4.3",
#     "lonboard==0.13.0",
#     "matplotlib==3.10.8",
#     "morecantile>=1.0.0",
#     "numpy==2.2.0",
#     "odc-stac==0.5.0",
#     "palettable==3.3.3",
#     "planetary-computer==1.0.0",
#     "pyarrow==18.1.0",
#     "pyproj==3.7.2",
#     "pystac-client==0.9.0"
# ]
# ///

# %%
import numpy as np
import pyarrow as pa
import duckdb
import morecantile
import odc.stac
import planetary_computer
import pystac_client
from matplotlib.colors import Normalize
from palettable.scientific.sequential import LaJolla_20, LaJolla_20_r, Bamako_20
from pyproj import Transformer
from arro3.core import Table

from lonboard import Map, H3HexagonLayer
from lonboard.colormap import apply_continuous_cmap

# %% [markdown]
# ## Pipeline Functions

# %%
def query_stac(bbox, collection):
    """Query Planetary Computer STAC catalog for items covering bbox."""
    catalog = pystac_client.Client.open(
        "https://planetarycomputer.microsoft.com/api/stac/v1",
        modifier=planetary_computer.sign_inplace,
    )
    items = catalog.search(
        collections=[collection],
        bbox=bbox,
        query={"gsd": {"eq": 10}} 
    ).item_collection()
    print(f"Found {len(items)} STAC items")
    return items


def get_tiles(bbox, zoom):
    """Split bbox into morecantile tiles at given zoom level."""
    tms = morecantile.tms.get("WebMercatorQuad")
    tiles = list(tms.tiles(*bbox, zooms=[zoom]))
    print(f"{len(tiles)} tiles at zoom {zoom}")
    return tiles, tms


def process_tile_to_h3(tile, tms, items, band, h3_res, con, transformer):
    """Load one tile's DEM, reproject to 4326, aggregate to H3 immediately.

    Returns Arrow table (hex, metric) or None on failure.
    """
    tile_bounds = tms.bounds(tile)
    tile_bbox = [tile_bounds.left, tile_bounds.bottom, tile_bounds.right, tile_bounds.top]

    try:
        ds = odc.stac.load(
            items,
            crs="EPSG:3857",
            resolution=100,
            bands=[band],
            bbox=tile_bbox,
        ).astype(float)
    except Exception:
        return None

    arr = ds[band].max(dim="time")
    vals = arr.values
    x_coords = arr.coords["x"].values
    y_coords = arr.coords["y"].values
    X, Y = np.meshgrid(x_coords, y_coords)
    lons, lats = transformer.transform(X.flatten(), Y.flatten())

    tile_pa = pa.table({
        "lat": pa.array(lats, type=pa.float64()),
        "lng": pa.array(lons, type=pa.float64()),
        "elevation": pa.array(vals.flatten(), type=pa.float64()),
    })

    result = con.sql(f"""
        SELECT
            h3_latlng_to_cell(lat, lng, {h3_res}) AS hex,
            AVG(elevation) AS metric
        FROM tile_pa
        GROUP BY 1
    """).fetch_arrow_table()
    return result


def process_all_tiles(items, tiles, tms, band, h3_res):
    """Process all tiles with per-tile H3 aggregation, then merge edge hexagons."""
    con = duckdb.connect()
    con.sql("INSTALL h3 FROM community; LOAD h3;")
    transformer = Transformer.from_crs("EPSG:3857", "EPSG:4326", always_xy=True)

    batches = []
    for i, tile in enumerate(tiles):
        result = process_tile_to_h3(tile, tms, items, band, h3_res, con, transformer)
        if result is not None and len(result) > 0:
            batches.append(result)
        if (i + 1) % 10 == 0 or i == len(tiles) - 1:
            print(f"  Processed {i + 1}/{len(tiles)} tiles")

    if not batches:
        con.close()
        raise RuntimeError("No tiles produced data")

    combined = pa.concat_tables(batches)
    print(f"Pre-merge hex count: {len(combined):,}")

    # Final merge: hexagons on tile edges appear in multiple batches
    hex_result = con.sql("""
        SELECT hex, AVG(metric) AS metric
        FROM combined
        GROUP BY 1
    """).fetch_arrow_table()
    con.close()

    print(f"Final H3 hexagons: {len(hex_result):,}")
    return hex_result

# %% [markdown]
# ## Configuration

# %%
# Grand Canyon bbox: west, south, east, north
# bbox = [-112.23047, 35.926336, -111.749034, 36.268266]
#bigger grand canyon bbox:
bbox =[-113.0606,35.8461,-111.7165,36.7665]
#yazoo city MS
# bbox = [-90.9642,32.6594,-90.109,33.477] # missed it
# cairo IL
# bbox = [-89.4436,36.91,-89.0463,37.1834]
# greenville MS
# bbox = [-91.3756,32.447,-90.859,33.9034]
# greater mount washington nh
# bbox = [-71.502182,44.092909,-70.723358,44.511611]
# bigger mount wash
# bbox= [-71.7445,43.8609,-70.602,44.7055]
COLLECTION = "3dep-seamless"
BAND = "data"
H3_RES = 12
TILE_ZOOM = 15

# %% [markdown]
# ## Run Pipeline

# %%
items = query_stac(bbox, COLLECTION)
tiles, tms = get_tiles(bbox, TILE_ZOOM)
hex_result = process_all_tiles(items, tiles, tms, BAND, H3_RES)
# Out:
# Found 6 STAC items
# 13020 tiles at zoom 15
#   Processed 10/13020 tiles
#   Processed 20/13020 tiles
#   Processed 30/13020 tiles
#   Processed 40/13020 tiles
#   Processed 50/13020 tiles
#   Processed 60/13020 tiles
#   Processed 70/13020 tiles
#   Processed 80/13020 tiles
#   Processed 90/13020 tiles
#   Processed 100/13020 tiles
#   Processed 110/13020 tiles
#   Processed 120/13020 tiles
#   Processed 130/13020 tiles
#   Processed 140/13020 tiles
#   Processed 150/13020 tiles
#   Processed 160/13020 tiles
#   Processed 170/13020 tiles
#   Processed 180/13020 tiles
#   Processed 190/13020 tiles
#   Processed 200/13020 tiles
#   Processed 210/13020 tiles
#   Processed 220/13020 tiles
#   Processed 230/13020 tiles
#   Processed 240/13020 tiles
#   Processed 250/13020 tiles
#   Processed 260/13020 tiles
#   Processed 270/13020 tiles
#   Processed 280/13020 tiles
#   Processed 290/13020 tiles
#   Processed 300/13020 tiles
#   Processed 310/13020 tiles
#   Processed 320/13020 tiles
#   Processed 330/13020 tiles
#   Processed 340/13020 tiles
#   Processed 350/13020 tiles
#   Processed 360/13020 tiles
#   Processed 370/13020 tiles
#   Processed 380/13020 tiles
#   Processed 390/13020 tiles
#   Processed 400/13020 tiles
#   Processed 410/13020 tiles
#   Processed 420/13020 tiles
#   Processed 430/13020 tiles
#   Processed 440/13020 tiles
#   Processed 450/13020 tiles
#   Processed 460/13020 tiles
#   Processed 470/13020 tiles
#   Processed 480/13020 tiles
#   Processed 490/13020 tiles
#   Processed 500/13020 tiles
#   Processed 510/13020 tiles
#   Processed 520/13020 tiles
#   Processed 530/13020 tiles
#   Processed 540/13020 tiles
#   Processed 550/13020 tiles
#   Processed 560/13020 tiles
#   Processed 570/13020 tiles
#   Processed 580/13020 tiles
#   Processed 590/13020 tiles
#   Processed 600/13020 tiles
#   Processed 610/13020 tiles
#   Processed 9520/13020 tiles
#   Processed 9530/13020 tiles
#   Processed 9540/13020 tiles
#   Processed 9550/13020 tiles
#   Processed 9560/13020 tiles
#   Processed 9570/13020 tiles
#   Processed 9580/13020 tiles
#   Processed 9590/13020 tiles
#   Processed 9600/13020 tiles
#   Processed 9610/13020 tiles
#   Processed 9620/13020 tiles
#   Processed 9630/13020 tiles
#   Processed 9640/13020 tiles
#   Processed 9650/13020 tiles
#   Processed 9660/13020 tiles
#   Processed 9670/13020 tiles
#   Processed 9680/13020 tiles
#   Processed 9690/13020 tiles
#   Processed 9700/13020 tiles
#   Processed 9710/13020 tiles
#   Processed 9720/13020 tiles
#   Processed 9730/13020 tiles
#   Processed 9740/13020 tiles
#   Processed 9750/13020 tiles
#   Processed 9760/13020 tiles
#   Processed 9770/13020 tiles
#   Processed 9780/13020 tiles
#   Processed 9790/13020 tiles
#   Processed 9800/13020 tiles
#   Processed 9810/13020 tiles
#   Processed 9820/13020 tiles
#   Processed 9830/13020 tiles
#   Processed 9840/13020 tiles
#   Processed 9850/13020 tiles
#   Processed 9860/13020 tiles
#   Processed 9870/13020 tiles
#   Processed 9880/13020 tiles
#   Processed 9890/13020 tiles
#   Processed 9900/13020 tiles
#   Processed 9910/13020 tiles
#   Processed 9920/13020 tiles
#   Processed 9930/13020 tiles
#   Processed 9940/13020 tiles
#   Processed 9950/13020 tiles
#   Processed 9960/13020 tiles
#   Processed 9970/13020 tiles
#   Processed 9980/13020 tiles
#   Processed 9990/13020 tiles
#   Processed 10000/13020 tiles
#   Processed 10010/13020 tiles
#   Processed 10020/13020 tiles
#   Processed 10030/13020 tiles
#   Processed 10040/13020 tiles
#   Processed 10050/13020 tiles
#   Processed 10060/13020 tiles
#   Processed 10070/13020 tiles
#   Processed 10080/13020 tiles
#   Processed 10090/13020 tiles
#   Processed 10100/13020 tiles
#   Processed 10110/13020 tiles
#   Processed 10120/13020 tiles
#   Processed 10130/13020 tiles
#   Processed 10140/13020 tiles
#   Processed 10150/13020 tiles
#   Processed 10160/13020 tiles
#   Processed 10170/13020 tiles
#   Processed 10180/13020 tiles
#   Processed 10190/13020 tiles
#   Processed 10200/13020 tiles
#   Processed 10210/13020 tiles
#   Processed 10220/13020 tiles
#   Processed 10230/13020 tiles
#   Processed 10240/13020 tiles
#   Processed 10250/13020 tiles
#   Processed 10260/13020 tiles
#   Processed 10270/13020 tiles
#   Processed 10280/13020 tiles
#   Processed 10290/13020 tiles
#   Processed 10300/13020 tiles
#   Processed 10310/13020 tiles
#   Processed 10320/13020 tiles
#   Processed 10330/13020 tiles
#   Processed 10340/13020 tiles
#   Processed 10350/13020 tiles
#   Processed 10360/13020 tiles
#   Processed 10370/13020 tiles
#   Processed 10380/13020 tiles
#   Processed 10390/13020 tiles
#   Processed 10400/13020 tiles
#   Processed 10410/13020 tiles
#   Processed 10420/13020 tiles
#   Processed 10430/13020 tiles
#   Processed 10440/13020 tiles
#   Processed 10450/13020 tiles
#   Processed 10460/13020 tiles
#   Processed 10470/13020 tiles
#   Processed 10480/13020 tiles
#   Processed 10490/13020 tiles
#   Processed 12480/13020 tiles
#   Processed 12490/13020 tiles
#   Processed 12500/13020 tiles
#   Processed 12510/13020 tiles
#   Processed 12520/13020 tiles
#   Processed 12530/13020 tiles
#   Processed 12540/13020 tiles
#   Processed 12550/13020 tiles
#   Processed 12560/13020 tiles
#   Processed 12570/13020 tiles
#   Processed 12580/13020 tiles
#   Processed 12590/13020 tiles
#   Processed 12600/13020 tiles
#   Processed 12610/13020 tiles
#   Processed 12620/13020 tiles
#   Processed 12630/13020 tiles
#   Processed 12640/13020 tiles
#   Processed 12650/13020 tiles
#   Processed 12660/13020 tiles
#   Processed 12670/13020 tiles
#   Processed 12680/13020 tiles
#   Processed 12690/13020 tiles
#   Processed 12700/13020 tiles
#   Processed 12710/13020 tiles
#   Processed 12720/13020 tiles
#   Processed 12730/13020 tiles
#   Processed 12740/13020 tiles
#   Processed 12750/13020 tiles
#   Processed 12760/13020 tiles
#   Processed 12770/13020 tiles
#   Processed 12780/13020 tiles
#   Processed 12790/13020 tiles
#   Processed 12800/13020 tiles
#   Processed 12810/13020 tiles
#   Processed 12820/13020 tiles
#   Processed 12830/13020 tiles
#   Processed 12840/13020 tiles
#   Processed 12850/13020 tiles
#   Processed 12860/13020 tiles
#   Processed 12870/13020 tiles
#   Processed 12880/13020 tiles
#   Processed 12890/13020 tiles
#   Processed 12900/13020 tiles
#   Processed 12910/13020 tiles
#   Processed 12920/13020 tiles
#   Processed 12930/13020 tiles
#   Processed 12940/13020 tiles
#   Processed 12950/13020 tiles
#   Processed 12960/13020 tiles
#   Processed 12970/13020 tiles
#   Processed 12980/13020 tiles
#   Processed 12990/13020 tiles
#   Processed 13000/13020 tiles
#   Processed 13010/13020 tiles
#   Processed 13020/13020 tiles
# Pre-merge hex count: 2,273,293
# Final H3 hexagons: 1,950,630

# %% [markdown]
# ## Visualize

# %%
# def build_map(hex_result, bbox, colormap=LaJolla_20_r, view_state=None):
# from palettable.matplotlib import Viridis_20_r

"""Build lonboard Map with extruded H3HexagonLayer."""
elev_values = hex_result["metric"].to_pylist()
elev_min = min(elev_values)
elev_max = max(elev_values)
colormap=LaJolla_20
                                                                                                                                             
# from matplotlib.colors import BoundaryNorm 
# boundaries = [23, 30, 34]                                                                                                               
  # evenly spaced across [0, 1]                                                                                                            
# normalized = np.interp(elev_values, boundaries, np.linspace(0, 1, len(boundaries)))     
normalizer = Normalize(elev_min , elev_max)
normalized = normalizer(elev_values)
colors = apply_continuous_cmap(normalized, colormap, alpha=1)

table = Table.from_arrow(hex_result)

layer = H3HexagonLayer(
    table=table,
    get_hexagon=table["hex"],
    get_fill_color=colors,
    high_precision=True, 
    stroked=False,
    get_elevation=table["metric"],
    extruded=False,
    elevation_scale=3.4,
    opacity=1,
)

# if view_state is None:
view_state = {
    "longitude": (bbox[0] + bbox[2]) / 2,
    "latitude": (bbox[1] + bbox[3]) / 2,
    "zoom": 15,
    "pitch": 55,
    "bearing": -20,
}

# %%
# from palettable.scientific.sequential import LaJolla_20, Bamako_20
m = Map(layers=[layer], view_state=view_state)
m

# %% [markdown]
# <!-- m.elevation_scale=30 -->
